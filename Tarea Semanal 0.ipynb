# %% [markdown]
# # Tarea semanal 0
#
# Alumno: Nicolas Gabriel Perez
#
# Sea el siguiente circuito:
#
# ![Captura desde 2026-04-22 20-37-17.png](attachment:87304964-6fc5-4678-a374-70298d8593c3.png)

# %% [markdown]
# ## Primer punto
#
# Se pide obtener la función transferencia del circuito :  módulo,fase y diagrama de polos y ceros.

# %%
## codigo usado para la obtensiom del modulo , ase y diagrama del circuito
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

w0 = 1000
k= 5
qq = np.sqrt(2)/2

my_tf = TransferFunction( [K,-K*w0], [1, w0] )

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )

pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq)) #S plane pole/zero plot

GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
# Out:
# (3,
#  <Axes: title={'center': 'Retardo de grupo'}, xlabel='Frecuencia angular [rad/seg]', ylabel='Retardo de grupo [seg]'>)

# %% [markdown]
# ## Segundo punto
# Se pide proponer una norma de frecuencia e impedancia  de forma tal de llegar a una transferencia normalizada
#
# Se propone para la frecuencia cambiar la resistencia R3 a un valor inversamente proporcional al capacitor C
# En respecto a la constante K sea igual a uno se propone que la resistencia R1 tenga el miso valor que la resistencia R2

# %% [markdown]
# ## Tercer punto
# Se pide la simulacion de la transferencia normalizada

# %%
## codigo usado para la obtensiom del modulo , ase y diagrama del circuito
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np

from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

w0 = 1
k = 5
qq = np.sqrt(2)/2

my_tf = TransferFunction( [k,-k*w0], [1, w0] )

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )

pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq)) #S plane pole/zero plot

GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
# Out:
# (3,
#  <Axes: title={'center': 'Retardo de grupo'}, xlabel='Frecuencia angular [rad/seg]', ylabel='Retardo de grupo [seg]'>)

# %% [markdown]
# ## Cuarto punto
# Se pide la simulacion de la red en LTspice y obtener la respuesta en frecuencia
#
# 1.Simulacion en LTspice:
#
# ![Circuito LTspice.png](attachment:0187a61f-9642-42b4-96b8-239ba8661e08.png)
#
# 2.Respuesta en frecuencia:
#
# Simulacion entrada V1:
#
# ![Entrada V1.png](attachment:01a735ec-005c-45a8-8ebc-54d82298bdce.png)
#
# Simulacion salida V2:
#
# ![Salida V2.png](attachment:1e73c804-44f8-411b-896a-57b0d7623aca.png)
#
# Respuesta en frecuencia:
#
# ![Respuesta en frecuencia.png](attachment:d9a049e4-0f5b-4619-af7e-b726387e7f6d.png)

# %% [markdown]
# ## Quinto punto
#
# Para finalizar se pide responder que filtro es
#
# El filtro es un filtro pasa todo
